# %% [markdown]
# <a href="https://colab.research.google.com/github/rajumark/QuantitativeLearning/blob/main/Proprietary_treding_example(No_Code).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proprietary treding example
#
# ## (1) Directional (Long/Short)
# (a) Long : We buy first and sell later , Profit if price goes up
# - This is common we all knows this. first thing
#
# (b) Short : Sell first then buy later
# - This make profit when price goes down.
#
# ## (b) Arbitrage
# - Risk free price diffrence
# - Example : Buy cheap from one place and sell to another place.
# - Like Gold price in mumbai is 1lakh and in dubai 90k then buy from dubai and sell at mumbai.
# - Profit is sort but risk is nealy very low.
# - Banks and big firms loves this.
#
# ## (c) Value trading.
# - Buy something cheap than it's real value.
# - Due to some events in market like political, events, bussiness growth or oil outrage will disturb the demand and supply so it will create prices up and down.
# - Compnaies that based on this share prices will also disturb so.
# - Sell share if prices are high comapre to it's normal value, (true value or real value)
# - Buy if share prices are low cause once market will be stable price will be normal.
#
# ## (d) Relative value
# - Comapre 2 similer assets
# - Example TCS and infosys are similer companies
# - if Infosys looks cheaper then buy it.
# - Like Buy infosys and sell TCS
# - Profit comes from diffrent closing, not from market direction.
#
# ## (e) Systematic Trading
# - Where human limits reach like, no matter how much powerfull IQ of Raju if he ans only 1 question at a time then he is limitation of human.
# - But computers do no have also we can replicate the computer (:(Not raju right. just kiding)
# - Rules + Computer+ Disiplin = Profit
# - No emotions
# - Example: If prices of last 50 days are going up then buy at 51 day and sell at 52 days. 1 day profit.
# - Example 2: If price of goes 10% down then sell all shares. so we can save 90% but here no human in loop
# - Used by mostly hadge funds and quant firms.
#
# ## (f) Momentum Trading
# - If any share prices are going up then we assume it will still go up like
# 100 > 110 > 120 > 130>
# - Momentum trader mostly buys at 110 and sell at next step or another next.
#
# ## (g) Statistical arbitrage
# - Use math and probalities to trade of tiny edge.
# - Example two stocks mostly move together.
# - Like when Products based on sugar like sugercandy shares goes up then it's consumer suger facotory also goes up.
# - In sort : Relation between 2 companies have strong relations in share movements. we track and find those couples.
# - We wait for one to behave abnormal like
# - Sugercandy prices goes up but suger fatory prices are not still going up.
# - We will purchase at that moment cause sometimes delay happens but probalities is high based on past data. so we puchase it.
# - Mostly used by Citadle, two sigma, Renaisaasnce.
#
# ## (i) Fundamental Analysis
# - We study the business, not charts
# - Like if Assume TCS, revenu, profit, Debt, Industry,
# - Like Companies growing 10% yearly so we buy then wait for long tearm.
# - Used by : Warren Buffett
#
# ## (j) Global Macro
# - Trade based on big world events
# - Like Interest rates changes
# - Inflations
# - Wars
# - Elections or political issue
# - Not good releation btween 2 countries so effect will be on import export and same for good relations.
#
# ## (k) Special situations
# - One Time event that change prices
# - Example : Merger, Acquisition, Bankruptchy, Spin-Off
#
# # Final conclusion
# - Retail(Normal people) do only 1 or 2 stratagies usage
# - Big firm use all them at once.(The more we use techniques the more confidant we will be, to meaure the risk.)
